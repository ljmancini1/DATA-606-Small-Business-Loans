# %%
conda install flask-restful
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask
from flask_restful import reqparse, abort, Api, Resource
import pickle
import numpy as np
from model import NLPModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-773d090f8098> in <module>
#       3 import pickle
#       4 import numpy as np
# ----> 5 from model import NLPModel
#
# ModuleNotFoundError: No module named 'model'

# %%
import pickle
from pydoc import locate
from typing import List

import numpy as np
import uvicorn
from fastapi import FastAPI
from pydantic import BaseModel

model = pickle.load(open("model.dat", "rb"))


def create_type_instance(type_name: str):
    return locate(type_name).__call__()


def get_features_dict(model):
    feature_names = model._get_param_names
    #feature_types = list(map(create_type_instance, model._get_param_names))
    return dict(zip(feature_names, ['float64']))


def create_input_features_class(model):
    return type("InputFeatures", (BaseModel,), get_features_dict(model))


InputFeatures = create_input_features_class(model)
app = FastAPI()


@app.post("/predict", response_model=List)
async def predict_post(datas: List[InputFeatures]):
    return model.predict(np.asarray([list(data.__dict__.values()) for data in datas])).tolist()


if __name__ == "__main__":
    print(get_features_dict(model))
    uvicorn.run(app, host="0.0.0.0", port=8080)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-58a53d417a0e> in <module>
#      25
#      26
# ---> 27 InputFeatures = create_input_features_class(model)
#      28 app = FastAPI()
#      29
#
# <ipython-input-19-58a53d417a0e> in create_input_features_class(model)
#      22
#      23 def create_input_features_class(model):
# ---> 24     return type("InputFeatures", (BaseModel,), get_features_dict(model))
#      25
#      26
#
# <ipython-input-19-58a53d417a0e> in get_features_dict(model)
#      18     feature_names = model._get_param_names
#      19     #feature_types = list(map(create_type_instance, model._get_param_names))
# ---> 20     return dict(zip(feature_names, ['float64']))
#      21
#      22
#
# TypeError: zip argument #1 must support iteration

# %%
pip install "uvicorn[standard]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "fastapi[all]"
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/6b/d2/c587a9cd8473041fd138b213fa12581a4e039d260cf24dfa07f5c9de78e4/email_validator-1.2.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9d/f6/7e91fbb58c9ee528759aea5892e062cccb426720c5830ddcce92eba00ff1/PyYAML-6.0-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9b/ed/28fb14146c7033ba0e89decd92a4fa16b0b69b84471e2deab3cc4337cc35/dnspython-2.2.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/f9/f8/13ffc95bf8a8c98d611b9f9fa5aa88625b9a82fce528e58f1aafba14946b/MarkupSafe-2.1.1-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
# flask 1.1.1 has requirement Werkzeug>=0.15, but you'll have werkzeug 0.14.1 which is incompatible.
# ...
#   Found existing installation: MarkupSafe 1.1.1
# ...

# %%
conda update Werkzeug
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/lenmancini/anaconda3
#
#   added / updated specs:
#     - werkzeug
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py37_0           6 KB
#     anaconda-client-1.9.0      |   py37hecd8cb5_0         149 KB
#     anaconda-project-0.10.2    |     pyhd3eb1b0_0         224 KB
#     anyqt-0.0.13               |     pyhd3eb1b0_0          42 KB
#     appdirs-1.4.4              |     pyhd3eb1b0_0          12 KB
#     applaunchservices-0.2.1    |     pyhd3eb1b0_0           9 KB
#     appnope-0.1.2              |py37hecd8cb5_1001          10 KB
#     appscript-1.1.2            |   py37h9ed2024_0         132 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py37hca72f7f_0          35 KB
# ...

# %%
import WerkZeug
print(WerkZeug.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-de1fb616007d> in <module>
# ----> 1 import WerkZeug
#       2 print(WerkZeug.__version__)
#
# ModuleNotFoundError: No module named 'WerkZeug'

# %%
pip install typing-extensions --upgrade

# %%
import xgboost as xgb

# %%
from sklearn.ensemble import GradientBoostingClassifier as gbc

# %%
dir(gbc)
# Out:
# ['_SUPPORTED_LOSS',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_initialized',
#  '_check_params',
#  '_clear_state',
#  '_decision_function',
#  '_estimator_type',
#  '_fit_stage',
#  '_fit_stages',
#  '_get_param_names',
#  '_init_decision_function',
#  '_init_state',
#  '_is_initialized',
#  '_make_estimator',
#  '_resize_state',
#  '_staged_decision_function',
#  '_validate_estimator',
#  '_validate_y',
#  'apply',
#  'decision_function',
#  'feature_importances_',
# ...

# %%
help(gbc._estimator_type)
# Out:
# No Python documentation found for 'classifier'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
